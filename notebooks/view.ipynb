# %% [markdown]
# ! alle Pakete installieren

# %% [markdown]
# # Pakete importieren

# %% [markdown]
# # Code

# %% [markdown]
# ## a) Anforderungen

# %% [markdown]
# ## b) Systemkomponenten

# %% [markdown]
# ## c) Zielgrößen

# %% [markdown]
# ## d) Simulationslauf

# %% [markdown]
# # Verbesserungen

# %% [markdown]
# ## a)
